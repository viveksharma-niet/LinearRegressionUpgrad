# %% [markdown]
# <a href="https://colab.research.google.com/github/viveksharma-niet/LinearRegressionUpgrad/blob/main/SimpleLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
advertising = pd.read_csv('/content/advertising.csv')
